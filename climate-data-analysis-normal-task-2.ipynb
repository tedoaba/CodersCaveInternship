# %% [markdown]
# # Climate Data Analysis
#
# Undertake a comprehensive climate data analysis project to explore and
# understand historical climate patterns and trends. The objective is to derive
# valuable insights from climate data, enabling a better understanding of weather
# conditions over time.

# %% [markdown]
# # 1. Project Setup
#
# **1.1 Environment Setup**
# - Install necessary libraries (e.g., pandas, numpy, matplotlib, seaborn).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 2. Data Collection and Loading

# %%
hourly = pd.read_csv('/kaggle/input/temperature-data-albany-new-york/hourly_data.csv')
hourly.head()
# Out:
# /tmp/ipykernel_112/887660567.py:1: DtypeWarning: Columns (11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   hourly = pd.read_csv('/kaggle/input/temperature-data-albany-new-york/hourly_data.csv')
#        STATION                 DATE REPORT_TYPE  SOURCE BackupElements  \
# 0  72518014735  2015-01-01T00:51:00       FM-15       7         PRECIP
# 1  72518014735  2015-01-01T01:51:00       FM-15       7         PRECIP
# 2  72518014735  2015-01-01T02:51:00       FM-15       7         PRECIP
# 3  72518014735  2015-01-01T03:51:00       FM-15       7         PRECIP
# 4  72518014735  2015-01-01T04:51:00       FM-15       7         PRECIP
#
#    BackupElevation BackupEquipment  BackupLatitude  BackupLongitude  \
# 0              260         PLASTIC         42.6918        -73.83109
# 1              260         PLASTIC         42.6918        -73.83109
# 2              260         PLASTIC         42.6918        -73.83109
# ...

# %%
daily = pd.read_csv('/kaggle/input/temperature-data-albany-new-york/daily_data.csv')
daily.head()
# Out:
#        STATION                 DATE REPORT_TYPE  SOURCE BackupElements  \
# 0  72518014735  2015-01-01T23:59:00       SOD         6         PRECIP
# 1  72518014735  2015-01-02T23:59:00       SOD         6         PRECIP
# 2  72518014735  2015-01-03T23:59:00       SOD         6         PRECIP
# 3  72518014735  2015-01-04T23:59:00       SOD         6         PRECIP
# 4  72518014735  2015-01-05T23:59:00       SOD         6         PRECIP
#
#    BackupElevation BackupEquipment  BackupLatitude  BackupLongitude  \
# 0              260         PLASTIC         42.6918        -73.83109
# 1              260         PLASTIC         42.6918        -73.83109
# 2              260         PLASTIC         42.6918        -73.83109
# 3              260         PLASTIC         42.6918        -73.83109
# 4              260         PLASTIC         42.6918        -73.83109
#
#        BackupName  ...  DailyPeakWindDirection  DailyPeakWindSpeed  \
# ...

# %%
monthly = pd.read_csv('/kaggle/input/temperature-data-albany-new-york/monthly_data.csv')
monthly.head()
# Out:
#        STATION                 DATE REPORT_TYPE  SOURCE  AWND BackupElements  \
# 0  72518014735  2015-01-31T23:59:00       SOM         6   8.9         PRECIP
# 1  72518014735  2015-02-28T23:59:00       SOM         6   8.7         PRECIP
# 2  72518014735  2015-03-31T23:59:00       SOM         6   9.4         PRECIP
# 3  72518014735  2015-04-30T23:59:00       SOM         6   9.4         PRECIP
# 4  72518014735  2015-05-31T23:59:00       SOM         6   8.3         PRECIP
#
#    BackupElevation BackupEquipment  BackupLatitude  BackupLongitude  ...  \
# 0              260         PLASTIC         42.6918        -73.83109  ...
# 1              260         PLASTIC         42.6918        -73.83109  ...
# 2              260         PLASTIC         42.6918        -73.83109  ...
# 3              260         PLASTIC         42.6918        -73.83109  ...
# 4              260         PLASTIC         42.6918        -73.83109  ...
#
#   MonthlyMeanTemperature  MonthlyMinSeaLevelPressureValue  \
# ...

# %%
three_hour = pd.read_csv('/kaggle/input/temperature-data-albany-new-york/three_hour_data.csv')
three_hour.head()
# Out:
#        STATION                 DATE REPORT_TYPE  SOURCE BackupElements  \
# 0  72518014735  2015-01-01T01:00:00       FM-12       4         PRECIP
# 1  72518014735  2015-01-01T04:00:00       FM-12       4         PRECIP
# 2  72518014735  2015-01-01T07:00:00       FM-12       4         PRECIP
# 3  72518014735  2015-01-01T10:00:00       FM-12       4         PRECIP
# 4  72518014735  2015-01-01T13:00:00       FM-12       4         PRECIP
#
#    BackupElevation BackupEquipment  BackupLatitude  BackupLongitude  \
# 0              260         PLASTIC         42.6918        -73.83109
# 1              260         PLASTIC         42.6918        -73.83109
# 2              260         PLASTIC         42.6918        -73.83109
# 3              260         PLASTIC         42.6918        -73.83109
# 4              260         PLASTIC         42.6918        -73.83109
#
#        BackupName  ... HourlyPressureChange HourlyPressureTendency  \
# ...

# %%
hourly.columns
# Out:
# Index(['STATION', 'DATE', 'REPORT_TYPE', 'SOURCE', 'BackupElements',
#        'BackupElevation', 'BackupEquipment', 'BackupLatitude',
#        'BackupLongitude', 'BackupName', 'HourlyAltimeterSetting',
#        'HourlyDewPointTemperature', 'HourlyDryBulbTemperature',
#        'HourlyPrecipitation', 'HourlyRelativeHumidity',
#        'HourlySeaLevelPressure', 'HourlyStationPressure', 'HourlyVisibility',
#        'HourlyWetBulbTemperature', 'HourlyWindDirection', 'HourlyWindSpeed',
#        'WindEquipmentChangeDate'],
#       dtype='object')

# %%
daily.columns
# Out:
# Index(['STATION', 'DATE', 'REPORT_TYPE', 'SOURCE', 'BackupElements',
#        'BackupElevation', 'BackupEquipment', 'BackupLatitude',
#        'BackupLongitude', 'BackupName', 'DailyAverageDewPointTemperature',
#        'DailyAverageDryBulbTemperature', 'DailyAverageRelativeHumidity',
#        'DailyAverageSeaLevelPressure', 'DailyAverageStationPressure',
#        'DailyAverageWetBulbTemperature', 'DailyAverageWindSpeed',
#        'DailyCoolingDegreeDays', 'DailyDepartureFromNormalAverageTemperature',
#        'DailyHeatingDegreeDays', 'DailyMaximumDryBulbTemperature',
#        'DailyMinimumDryBulbTemperature', 'DailyPeakWindDirection',
#        'DailyPeakWindSpeed', 'DailyPrecipitation', 'DailySnowDepth',
#        'DailySnowfall', 'DailySustainedWindDirection',
#        'DailySustainedWindSpeed', 'Sunrise', 'Sunset',
#        'WindEquipmentChangeDate'],
#       dtype='object')

# %%
monthly.columns
# Out:
# Index(['STATION', 'DATE', 'REPORT_TYPE', 'SOURCE', 'AWND', 'BackupElements',
#        'BackupElevation', 'BackupEquipment', 'BackupLatitude',
#        'BackupLongitude', 'BackupName', 'CDSD', 'CLDD', 'DSNW', 'HDSD', 'HTDD',
#        'MonthlyDaysWithGT001Precip', 'MonthlyDaysWithGT010Precip',
#        'MonthlyDaysWithGT32Temp', 'MonthlyDaysWithGT90Temp',
#        'MonthlyDaysWithLT0Temp', 'MonthlyDaysWithLT32Temp',
#        'MonthlyDepartureFromNormalAverageTemperature',
#        'MonthlyDepartureFromNormalCoolingDegreeDays',
#        'MonthlyDepartureFromNormalHeatingDegreeDays',
#        'MonthlyDepartureFromNormalMaximumTemperature',
#        'MonthlyDepartureFromNormalMinimumTemperature',
#        'MonthlyDepartureFromNormalPrecipitation', 'MonthlyGreatestPrecip',
#        'MonthlyGreatestPrecipDate', 'MonthlyGreatestSnowDepth',
#        'MonthlyGreatestSnowfall', 'MonthlyMaxSeaLevelPressureValue',
#        'MonthlyMaxSeaLevelPressureValueDate',
# ...

# %%
three_hour.columns
# Out:
# Index(['STATION', 'DATE', 'REPORT_TYPE', 'SOURCE', 'BackupElements',
#        'BackupElevation', 'BackupEquipment', 'BackupLatitude',
#        'BackupLongitude', 'BackupName', 'HourlyDewPointTemperature',
#        'HourlyDryBulbTemperature', 'HourlyPressureChange',
#        'HourlyPressureTendency', 'HourlyRelativeHumidity',
#        'HourlySeaLevelPressure', 'HourlyStationPressure', 'HourlyVisibility',
#        'HourlyWetBulbTemperature', 'HourlyWindDirection', 'HourlyWindSpeed',
#        'WindEquipmentChangeDate'],
#       dtype='object')

# %%
hourly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64729 entries, 0 to 64728
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   STATION                    64729 non-null  int64
#  1   DATE                       64729 non-null  object
#  2   REPORT_TYPE                64729 non-null  object
#  3   SOURCE                     64729 non-null  int64
#  4   BackupElements             64729 non-null  object
#  5   BackupElevation            64729 non-null  int64
#  6   BackupEquipment            64729 non-null  object
#  7   BackupLatitude             64729 non-null  float64
#  8   BackupLongitude            64729 non-null  float64
#  9   BackupName                 64729 non-null  object
#  10  HourlyAltimeterSetting     64729 non-null  object
#  11  HourlyDewPointTemperature  64729 non-null  object
#  12  HourlyDryBulbTemperature   64729 non-null  object
# ...

# %%
daily.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2668 entries, 0 to 2667
# Data columns (total 32 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   STATION                                     2668 non-null   int64
#  1   DATE                                        2668 non-null   object
#  2   REPORT_TYPE                                 2668 non-null   object
#  3   SOURCE                                      2668 non-null   int64
#  4   BackupElements                              2668 non-null   object
#  5   BackupElevation                             2668 non-null   int64
#  6   BackupEquipment                             2668 non-null   object
#  7   BackupLatitude                              2668 non-null   float64
#  8   BackupLongitude                             2668 non-null   float64
#  9   BackupName                                  2668 non-null   object
# ...

# %%
monthly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 46 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   STATION                                       87 non-null     int64
#  1   DATE                                          87 non-null     object
#  2   REPORT_TYPE                                   87 non-null     object
#  3   SOURCE                                        87 non-null     int64
#  4   AWND                                          87 non-null     float64
#  5   BackupElements                                87 non-null     object
#  6   BackupElevation                               87 non-null     int64
#  7   BackupEquipment                               87 non-null     object
#  8   BackupLatitude                                87 non-null     float64
# ...

# %%
three_hour.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20843 entries, 0 to 20842
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   STATION                    20843 non-null  int64
#  1   DATE                       20843 non-null  object
#  2   REPORT_TYPE                20843 non-null  object
#  3   SOURCE                     20843 non-null  int64
#  4   BackupElements             20843 non-null  object
#  5   BackupElevation            20843 non-null  int64
#  6   BackupEquipment            20843 non-null  object
#  7   BackupLatitude             20843 non-null  float64
#  8   BackupLongitude            20843 non-null  float64
#  9   BackupName                 20843 non-null  object
#  10  HourlyDewPointTemperature  20843 non-null  object
#  11  HourlyDryBulbTemperature   20843 non-null  object
#  12  HourlyPressureChange       20843 non-null  float64
# ...

# %%
hourly.isnull().sum()
# Out:
# STATION                      0
# DATE                         0
# REPORT_TYPE                  0
# SOURCE                       0
# BackupElements               0
# BackupElevation              0
# BackupEquipment              0
# BackupLatitude               0
# BackupLongitude              0
# BackupName                   0
# HourlyAltimeterSetting       0
# HourlyDewPointTemperature    0
# HourlyDryBulbTemperature     0
# HourlyPrecipitation          0
# HourlyRelativeHumidity       0
# HourlySeaLevelPressure       0
# HourlyStationPressure        0
# HourlyVisibility             0
# HourlyWetBulbTemperature     0
# HourlyWindDirection          0
# HourlyWindSpeed              0
# WindEquipmentChangeDate      0
# dtype: int64

# %%
daily.isnull().sum()
# Out:
# STATION                                       0
# DATE                                          0
# REPORT_TYPE                                   0
# SOURCE                                        0
# BackupElements                                0
# BackupElevation                               0
# BackupEquipment                               0
# BackupLatitude                                0
# BackupLongitude                               0
# BackupName                                    0
# DailyAverageDewPointTemperature               0
# DailyAverageDryBulbTemperature                0
# DailyAverageRelativeHumidity                  0
# DailyAverageSeaLevelPressure                  0
# DailyAverageStationPressure                   0
# DailyAverageWetBulbTemperature                0
# DailyAverageWindSpeed                         0
# DailyCoolingDegreeDays                        0
# DailyDepartureFromNormalAverageTemperature    0
# DailyHeatingDegreeDays                        0
# ...

# %%
monthly.isnull().sum()
# Out:
# STATION                                         0
# DATE                                            0
# REPORT_TYPE                                     0
# SOURCE                                          0
# AWND                                            0
# BackupElements                                  0
# BackupElevation                                 0
# BackupEquipment                                 0
# BackupLatitude                                  0
# BackupLongitude                                 0
# BackupName                                      0
# CDSD                                            0
# CLDD                                            0
# DSNW                                            0
# HDSD                                            0
# HTDD                                            0
# MonthlyDaysWithGT001Precip                      0
# MonthlyDaysWithGT010Precip                      0
# MonthlyDaysWithGT32Temp                         0
# ...

# %%
three_hour.isnull().sum()
# Out:
# STATION                      0
# DATE                         0
# REPORT_TYPE                  0
# SOURCE                       0
# BackupElements               0
# BackupElevation              0
# BackupEquipment              0
# BackupLatitude               0
# BackupLongitude              0
# BackupName                   0
# HourlyDewPointTemperature    0
# HourlyDryBulbTemperature     0
# HourlyPressureChange         0
# HourlyPressureTendency       0
# HourlyRelativeHumidity       0
# HourlySeaLevelPressure       0
# HourlyStationPressure        0
# HourlyVisibility             0
# HourlyWetBulbTemperature     0
# HourlyWindDirection          0
# HourlyWindSpeed              0
# WindEquipmentChangeDate      0
# dtype: int64

# %% [markdown]
# **No Missing Value in all of the datasets**

# %%
hourly.shape, daily.shape, monthly.shape, three_hour.shape
# Out:
# ((64729, 22), (2668, 32), (87, 46), (20843, 22))

# %% [markdown]
# # 3. Data Cleaning

# %%
# Remove suspect values
daily = daily.replace('s', pd.NA)
hourly = hourly.replace('s', pd.NA)
monthly = monthly.replace('s', pd.NA)
three_hour = three_hour.replace('s', pd.NA)

# %%
# Remove trace precipitation amounts
daily = daily.replace('T', pd.NA)
hourly = hourly.replace('T', pd.NA)
monthly = monthly.replace('T', pd.NA)
three_hour = three_hour.replace('T', pd.NA)

# %%
# Remove missing values
daily = daily.dropna()
hourly = hourly.dropna()
monthly = monthly.dropna()
three_hour = three_hour.dropna()

# %%
# Remove variable wind directions
daily = daily[daily['DailyPeakWindDirection'] != 'VRB']
hourly = hourly[hourly['HourlyWindDirection'] != 'VRB']
three_hour = three_hour[three_hour['HourlyWindDirection'] != 'VRB']

# %%
daily.head()
# Out:
#        STATION                 DATE REPORT_TYPE  SOURCE BackupElements  \
# 0  72518014735  2015-01-01T23:59:00       SOD         6         PRECIP
# 2  72518014735  2015-01-03T23:59:00       SOD         6         PRECIP
# 3  72518014735  2015-01-04T23:59:00       SOD         6         PRECIP
# 5  72518014735  2015-01-06T23:59:00       SOD         6         PRECIP
# 8  72518014735  2015-01-09T23:59:00       SOD         6         PRECIP
#
#    BackupElevation BackupEquipment  BackupLatitude  BackupLongitude  \
# 0              260         PLASTIC         42.6918        -73.83109
# 2              260         PLASTIC         42.6918        -73.83109
# 3              260         PLASTIC         42.6918        -73.83109
# 5              260         PLASTIC         42.6918        -73.83109
# 8              260         PLASTIC         42.6918        -73.83109
#
#        BackupName  ...  DailyPeakWindDirection  DailyPeakWindSpeed  \
# ...

# %%
hourly.head()
# Out:
#        STATION                 DATE REPORT_TYPE  SOURCE BackupElements  \
# 0  72518014735  2015-01-01T00:51:00       FM-15       7         PRECIP
# 1  72518014735  2015-01-01T01:51:00       FM-15       7         PRECIP
# 2  72518014735  2015-01-01T02:51:00       FM-15       7         PRECIP
# 3  72518014735  2015-01-01T03:51:00       FM-15       7         PRECIP
# 4  72518014735  2015-01-01T04:51:00       FM-15       7         PRECIP
#
#    BackupElevation BackupEquipment  BackupLatitude  BackupLongitude  \
# 0              260         PLASTIC         42.6918        -73.83109
# 1              260         PLASTIC         42.6918        -73.83109
# 2              260         PLASTIC         42.6918        -73.83109
# 3              260         PLASTIC         42.6918        -73.83109
# 4              260         PLASTIC         42.6918        -73.83109
#
#        BackupName  ... HourlyDryBulbTemperature HourlyPrecipitation  \
# ...

# %%
three_hour.head()
# Out:
#        STATION                 DATE REPORT_TYPE  SOURCE BackupElements  \
# 0  72518014735  2015-01-01T01:00:00       FM-12       4         PRECIP
# 1  72518014735  2015-01-01T04:00:00       FM-12       4         PRECIP
# 2  72518014735  2015-01-01T07:00:00       FM-12       4         PRECIP
# 3  72518014735  2015-01-01T10:00:00       FM-12       4         PRECIP
# 4  72518014735  2015-01-01T13:00:00       FM-12       4         PRECIP
#
#    BackupElevation BackupEquipment  BackupLatitude  BackupLongitude  \
# 0              260         PLASTIC         42.6918        -73.83109
# 1              260         PLASTIC         42.6918        -73.83109
# 2              260         PLASTIC         42.6918        -73.83109
# 3              260         PLASTIC         42.6918        -73.83109
# 4              260         PLASTIC         42.6918        -73.83109
#
#        BackupName  ... HourlyPressureChange HourlyPressureTendency  \
# ...

# %% [markdown]
# # 4. Data Preprocessing

# %%
# Preprocess the daily data
daily = daily.dropna()
daily = daily[daily['REPORT_TYPE'].str.strip() == 'SOD']

# Preprocess the hourly data
hourly = hourly.dropna()
hourly = hourly[hourly['REPORT_TYPE'].str.strip() == 'FM-15']

# Preprocess the monthly data
monthly = monthly.dropna()
monthly = monthly[monthly['REPORT_TYPE'].str.strip() == 'SOM']

# Preprocess the three-hour data
three_hour = three_hour.dropna()
three_hour = three_hour[three_hour['REPORT_TYPE'].str.strip() == 'FM-12']

# %%
daily.head()
# Out:
#        STATION                 DATE REPORT_TYPE  SOURCE BackupElements  \
# 0  72518014735  2015-01-01T23:59:00       SOD         6         PRECIP
# 2  72518014735  2015-01-03T23:59:00       SOD         6         PRECIP
# 3  72518014735  2015-01-04T23:59:00       SOD         6         PRECIP
# 5  72518014735  2015-01-06T23:59:00       SOD         6         PRECIP
# 8  72518014735  2015-01-09T23:59:00       SOD         6         PRECIP
#
#    BackupElevation BackupEquipment  BackupLatitude  BackupLongitude  \
# 0              260         PLASTIC         42.6918        -73.83109
# 2              260         PLASTIC         42.6918        -73.83109
# 3              260         PLASTIC         42.6918        -73.83109
# 5              260         PLASTIC         42.6918        -73.83109
# 8              260         PLASTIC         42.6918        -73.83109
#
#        BackupName  ...  DailyPeakWindDirection  DailyPeakWindSpeed  \
# ...

# %%
hourly.head()
# Out:
#        STATION                 DATE REPORT_TYPE  SOURCE BackupElements  \
# 0  72518014735  2015-01-01T00:51:00       FM-15       7         PRECIP
# 1  72518014735  2015-01-01T01:51:00       FM-15       7         PRECIP
# 2  72518014735  2015-01-01T02:51:00       FM-15       7         PRECIP
# 3  72518014735  2015-01-01T03:51:00       FM-15       7         PRECIP
# 4  72518014735  2015-01-01T04:51:00       FM-15       7         PRECIP
#
#    BackupElevation BackupEquipment  BackupLatitude  BackupLongitude  \
# 0              260         PLASTIC         42.6918        -73.83109
# 1              260         PLASTIC         42.6918        -73.83109
# 2              260         PLASTIC         42.6918        -73.83109
# 3              260         PLASTIC         42.6918        -73.83109
# 4              260         PLASTIC         42.6918        -73.83109
#
#        BackupName  ... HourlyDryBulbTemperature HourlyPrecipitation  \
# ...

# %%
monthly.head()
# Out:
#        STATION                 DATE REPORT_TYPE  SOURCE  AWND BackupElements  \
# 0  72518014735  2015-01-31T23:59:00       SOM         6   8.9         PRECIP
# 1  72518014735  2015-02-28T23:59:00       SOM         6   8.7         PRECIP
# 2  72518014735  2015-03-31T23:59:00       SOM         6   9.4         PRECIP
# 3  72518014735  2015-04-30T23:59:00       SOM         6   9.4         PRECIP
# 4  72518014735  2015-05-31T23:59:00       SOM         6   8.3         PRECIP
#
#    BackupElevation BackupEquipment  BackupLatitude  BackupLongitude  ...  \
# 0              260         PLASTIC         42.6918        -73.83109  ...
# 1              260         PLASTIC         42.6918        -73.83109  ...
# 2              260         PLASTIC         42.6918        -73.83109  ...
# 3              260         PLASTIC         42.6918        -73.83109  ...
# 4              260         PLASTIC         42.6918        -73.83109  ...
#
#   MonthlyMeanTemperature  MonthlyMinSeaLevelPressureValue  \
# ...

# %%
three_hour.head()
# Out:
#        STATION                 DATE REPORT_TYPE  SOURCE BackupElements  \
# 0  72518014735  2015-01-01T01:00:00       FM-12       4         PRECIP
# 1  72518014735  2015-01-01T04:00:00       FM-12       4         PRECIP
# 2  72518014735  2015-01-01T07:00:00       FM-12       4         PRECIP
# 3  72518014735  2015-01-01T10:00:00       FM-12       4         PRECIP
# 4  72518014735  2015-01-01T13:00:00       FM-12       4         PRECIP
#
#    BackupElevation BackupEquipment  BackupLatitude  BackupLongitude  \
# 0              260         PLASTIC         42.6918        -73.83109
# 1              260         PLASTIC         42.6918        -73.83109
# 2              260         PLASTIC         42.6918        -73.83109
# 3              260         PLASTIC         42.6918        -73.83109
# 4              260         PLASTIC         42.6918        -73.83109
#
#        BackupName  ... HourlyPressureChange HourlyPressureTendency  \
# ...

# %% [markdown]
# # 5. Exploratory Data Analysis - EDA

# %% [markdown]
# ## 5.1 Distribution of variables

# %%
# Histogram of temperature in daily data
plt.figure(figsize=(8, 6))
sns.histplot(daily['DailyAverageDryBulbTemperature'], bins=20, kde=True, color='blue')
plt.title('Distribution of Daily Average Temperature')
plt.xlabel('Temperature (°F)')
plt.ylabel('Frequency')
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## 5.2 Relationship between variables

# %%
# Scatter plot of temperature and precipitation in monthly data
plt.figure(figsize=(8, 6))
sns.scatterplot(x='MonthlyMeanTemperature', y='MonthlyTotalLiquidPrecipitation', data=monthly)
plt.title('Relationship between Monthly Mean Temperature and Total Precipitation')
plt.xlabel('Mean Temperature (°F)')
plt.ylabel('Total Precipitation (inches)')
plt.show()

# %% [markdown]
# ## 5.3 Correlation matrix

# %%
# Correlation matrix for hourly data
numeric_columns = hourly.select_dtypes(include=['float64', 'int64']).columns
correlation_matrix = hourly[numeric_columns].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f")
plt.title('Correlation Matrix for Hourly Data')
plt.show()

# %% [markdown]
# ## 5.4 Distribution of Precipitation Types

# %%
precipitation_counts = daily['DailyPrecipitation'].value_counts()

# Plotting the pie chart with larger figure size and smaller font size for labels
plt.figure(figsize=(20, 18))
plt.pie(precipitation_counts, labels=[f'{label} ({count})' for label, count in zip(precipitation_counts.index, precipitation_counts)],
        autopct='%1.1f%%', startangle=140, textprops={'fontsize': 10})
plt.title('Distribution of Precipitation Types')
plt.axis('equal')  
plt.legend(loc='upper right')  
plt.show()

# %% [markdown]
# ## 5.5 Monthly Aggregation

# %%
# Load the daily dataset
daily = pd.read_csv('/kaggle/input/temperature-data-albany-new-york/daily_data.csv', parse_dates=['DATE'], na_values=['s', 'T', 'M'])
# Create a new column for the month
daily['Month'] = daily['DATE'].dt.month

# Calculate average temperature and precipitation per month
monthly_aggregations = daily.groupby('Month').agg({'DailyAverageDryBulbTemperature': 'mean', 'DailyPrecipitation': 'sum'})

# Display monthly aggregations
print("Monthly Aggregations:")
print(monthly_aggregations)
# Out:
# Monthly Aggregations:
#        DailyAverageDryBulbTemperature  DailyPrecipitation
# Month
# 1                           25.202429               18.36
# 2                           29.705584               19.94
# 3                           36.434959               18.76
# 4                           47.587500               27.35
# 5                           60.750000               20.62
# 6                           68.545455               26.96
# 7                           73.830986               35.11
# 8                           72.060185               29.82
# 9                           64.980952               28.02
# 10                          53.101852               30.46
# 11                          40.162679               19.91
# 12                          32.410138               21.28

# %% [markdown]
# ## 5.6 Average Daily Temprature

# %%
# Example Pandas query
average_daily_temperature = daily.groupby('DATE')['DailyAverageDryBulbTemperature'].mean()
print("Average Daily Temperature:")
print(average_daily_temperature)
# Out:
# Average Daily Temperature:
# DATE
# 2015-01-01 23:59:00    25.0
# 2015-01-02 23:59:00    32.0
# 2015-01-03 23:59:00    27.0
# 2015-01-04 23:59:00    39.0
# 2015-01-05 23:59:00    27.0
#                        ...
# 2022-05-27 23:59:00    70.0
# 2022-05-28 23:59:00    68.0
# 2022-05-29 23:59:00    66.0
# 2022-05-30 23:59:00    72.0
# 2022-05-31 23:59:00    79.0
# Name: DailyAverageDryBulbTemperature, Length: 2668, dtype: float64

# %% [markdown]
# #### Extreme Temprature Day

# %%
# Identify days with extreme temperatures (e.g., above 90°F)
extreme_temperature_days = daily[daily['DailyMaximumDryBulbTemperature'] > 90]

# Display information about extreme temperature days
print("Extreme Temperature Days:")
print(extreme_temperature_days[['DATE', 'DailyMaximumDryBulbTemperature']])
# Out:
# Extreme Temperature Days:
#                     DATE  DailyMaximumDryBulbTemperature
# 171  2015-07-19 23:59:00                            91.0
# 180  2015-07-28 23:59:00                            93.0
# 181  2015-07-29 23:59:00                            95.0
# 200  2015-08-18 23:59:00                            91.0
# 220  2015-09-07 23:59:00                            92.0
# ...                  ...                             ...
# 1986 2020-07-19 23:59:00                            93.0
# 1994 2020-07-27 23:59:00                            93.0
# 2331 2021-06-29 23:59:00                            92.0
# 2657 2022-05-21 23:59:00                            91.0
# 2667 2022-05-31 23:59:00                            92.0
#
# [61 rows x 2 columns]

# %% [markdown]
# # 6. Data Visualization

# %% [markdown]
# ## 6.1 Precipitation over Time

# %%
# Visualize precipitation over time
plt.figure(figsize=(12, 6))
plt.plot(daily['DATE'], daily['DailyPrecipitation'], label='Daily Precipitation')
plt.title('Daily Precipitation Trends')
plt.xlabel('Date')
plt.ylabel('Precipitation (inches)')
plt.legend()
plt.show()

# %% [markdown]
# ## 6.2 Humidity over Time

# %%
# Visualize humidity over time
plt.figure(figsize=(12, 6))
plt.plot(daily['DATE'], daily['DailyAverageRelativeHumidity'], label='Daily Average Relative Humidity')
plt.title('Daily Average Relative Humidity Trends')
plt.xlabel('Date')
plt.ylabel('Relative Humidity (%)')
plt.legend()
plt.show()

# %% [markdown]
# ## 6.3 Speed over Time

# %%
# Visualize wind speed over time
plt.figure(figsize=(12, 6))
plt.plot(daily['DATE'], daily['DailyAverageWindSpeed'], label='Daily Average Wind Speed')
plt.title('Daily Average Wind Speed Trends')
plt.xlabel('Date')
plt.ylabel('Wind Speed (mph)')
plt.legend()
plt.show()

# %% [markdown]
# ## 6.4 Temprature Trends

# %%
# Visualize trends over time
plt.figure(figsize=(12, 6))
plt.plot(daily['DATE'], daily['DailyAverageDryBulbTemperature'], label='Daily Average Temperature')
plt.title('Daily Average Temperature Trends')
plt.xlabel('Date')
plt.ylabel('Temperature (°F)')
plt.legend()
plt.show()

# %% [markdown]
# ## 6.5 Distribution of Wind Directions

# %%
# Visualize distribution of wind directions
plt.figure(figsize=(12, 6))
plt.hist(daily['DailyPeakWindDirection'].dropna(), bins=360, range=(0, 360), density=True, alpha=0.7)
plt.title('Distribution of Daily Peak Wind Directions')
plt.xlabel('Wind Direction (degrees)')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# ## 6.6 Distribution of Daily Precipitation

# %%
# Visualize the distribution of daily precipitation
plt.figure(figsize=(12, 6))
plt.hist(daily['DailyPrecipitation'].dropna(), bins=30, edgecolor='black')
plt.title('Distribution of Daily Precipitation')
plt.xlabel('Precipitation (inches)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## 6.7 Monthly Average Temprature

# %%
# Create a new column for the month
daily['Month'] = daily['DATE'].dt.month

# Calculate average temperature per month
monthly_temperature = daily.groupby('Month')['DailyAverageDryBulbTemperature'].mean()

# Visualize trends in monthly average temperature
plt.figure(figsize=(12, 6))
plt.plot(monthly_temperature.index, monthly_temperature.values, marker='o')
plt.title('Monthly Average Temperature Trends')
plt.xlabel('Month')
plt.ylabel('Average Temperature (°F)')
plt.show()

# %% [markdown]
# ## 6.8 Distribution of Daily Average Wind Speed

# %%
# Visualize the distribution of daily average wind speed
plt.figure(figsize=(12, 6))
plt.hist(daily['DailyAverageWindSpeed'].dropna(), bins=30, edgecolor='black')
plt.title('Distribution of Daily Average Wind Speed')
plt.xlabel('Wind Speed (mph)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## 6.9 Daily Temprature Range

# %%
# Calculate daily temperature range
daily['TemperatureRange'] = daily['DailyMaximumDryBulbTemperature'] - daily['DailyMinimumDryBulbTemperature']

# Visualize trends in daily temperature range
plt.figure(figsize=(12, 6))
plt.plot(daily['DATE'], daily['TemperatureRange'], label='Daily Temperature Range')
plt.title('Daily Temperature Range Trends')
plt.xlabel('Date')
plt.ylabel('Temperature Range (°F)')
plt.legend()
plt.show()

# %% [markdown]
# ## 6.10 Seasonal Average Temprature

# %%
# Extract the season from the date (e.g., Winter, Spring, Summer, Fall)
daily['Season'] = (daily['DATE'].dt.month % 12 + 3) // 3

# Calculate average temperature per season
seasonal_temperature = daily.groupby('Season')['DailyAverageDryBulbTemperature'].mean()

# Visualize trends in seasonal average temperature
plt.figure(figsize=(12, 6))
plt.plot(seasonal_temperature.index, seasonal_temperature.values, marker='o')
plt.title('Seasonal Average Temperature Trends')
plt.xlabel('Season')
plt.ylabel('Average Temperature (°F)')
plt.xticks([1, 2, 3, 4], ['Winter', 'Spring', 'Summer', 'Fall'])
plt.show()

# %% [markdown]
# ## 6.11 Average Monthly Wind Speed

# %%
# Calculate average monthly wind speed
monthly_wind_speed = daily.groupby(daily['DATE'].dt.to_period("M"))['DailyAverageWindSpeed'].mean()

# Visualize trends in monthly average wind speed
plt.figure(figsize=(12, 6))
plt.bar(monthly_wind_speed.index.astype(str), monthly_wind_speed.values)
plt.title('Monthly Average Wind Speed Trends')
plt.xlabel('Month')
plt.ylabel('Average Wind Speed (mph)')
plt.show()

# %% [markdown]
# # 7. Dataset Merging

# %% [markdown]
# ## 7.1 Select Common Columns

# %%
# Load the datasets
daily_data = pd.read_csv('/kaggle/input/temperature-data-albany-new-york/daily_data.csv', na_values=['SOD  ', 'PRECIP', 'other_non_numeric_values'])
hourly_data = pd.read_csv('/kaggle/input/temperature-data-albany-new-york/hourly_data.csv', na_values=['SOD  ', 'PRECIP', 'other_non_numeric_values'])
monthly_data = pd.read_csv('/kaggle/input/temperature-data-albany-new-york/monthly_data.csv', na_values=['SOD  ', 'PRECIP', 'other_non_numeric_values'])
three_hour_data = pd.read_csv('/kaggle/input/temperature-data-albany-new-york/three_hour_data.csv', na_values=['SOD  ', 'PRECIP', 'other_non_numeric_values'])

# Identify common columns among datasets
common_columns = set(daily_data.columns) & set(hourly_data.columns) & set(monthly_data.columns) & set(three_hour_data.columns)

# Print common columns
print("Common columns:", common_columns)
# Out:
# Common columns: {'BackupLatitude', 'SOURCE', 'DATE', 'BackupName', 'BackupLongitude', 'BackupElevation', 'REPORT_TYPE', 'STATION', 'BackupEquipment', 'BackupElements', 'WindEquipmentChangeDate'}
# /tmp/ipykernel_112/3052475985.py:5: DtypeWarning: Columns (11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   hourly_data = pd.read_csv('/kaggle/input/temperature-data-albany-new-york/hourly_data.csv', na_values=['SOD  ', 'PRECIP', 'other_non_numeric_values'])

# %% [markdown]
# ## 7.2 Merge dataset based on selected columns

# %%
# Load the datasets
daily_data = pd.read_csv('/kaggle/input/temperature-data-albany-new-york/daily_data.csv', parse_dates=['DATE'], na_values=['SOD  ', 'PRECIP', 'other_non_numeric_values'])
hourly_data = pd.read_csv('/kaggle/input/temperature-data-albany-new-york/hourly_data.csv', parse_dates=['DATE'], na_values=['SOD  ', 'PRECIP', 'other_non_numeric_values'])
monthly_data = pd.read_csv('/kaggle/input/temperature-data-albany-new-york/monthly_data.csv', parse_dates=['DATE'], na_values=['SOD  ', 'PRECIP', 'other_non_numeric_values'])
three_hour_data = pd.read_csv('/kaggle/input/temperature-data-albany-new-york/three_hour_data.csv', parse_dates=['DATE'], na_values=['SOD  ', 'PRECIP', 'other_non_numeric_values'])

# Merge the datasets based on 'DATE' with different suffixes
merged_data = pd.merge(daily_data, hourly_data, on='DATE', how='outer', suffixes=('_daily', '_hourly'))
merged_data = pd.merge(merged_data, monthly_data, on='DATE', how='outer', suffixes=('_merged', '_monthly'))
merged_data = pd.merge(merged_data, three_hour_data, on='DATE', how='outer', suffixes=('_merged', '_three_hour'))

# Display the merged dataset
print("Merged Dataset:")
merged_data.head()
# Out:
# /tmp/ipykernel_112/1355856105.py:3: DtypeWarning: Columns (11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   hourly_data = pd.read_csv('/kaggle/input/temperature-data-albany-new-york/hourly_data.csv', parse_dates=['DATE'], na_values=['SOD  ', 'PRECIP', 'other_non_numeric_values'])
# Merged Dataset:
#    STATION_daily                DATE  REPORT_TYPE_daily  SOURCE_daily  \
# 0            NaN 2015-01-01 00:51:00                NaN           NaN
# 1            NaN 2015-01-01 01:00:00                NaN           NaN
# 2            NaN 2015-01-01 01:51:00                NaN           NaN
# 3            NaN 2015-01-01 02:51:00                NaN           NaN
# 4            NaN 2015-01-01 03:51:00                NaN           NaN
#
#    BackupElements_daily  BackupElevation_daily BackupEquipment_daily  \
# 0                   NaN                    NaN                   NaN
# 1                   NaN                    NaN                   NaN
# ...

# %%
# Identify columns with mixed types in hourly_data
mixed_type_columns = hourly_data.iloc[:, [11, 12]].columns
print("Columns with mixed types in hourly_data:", mixed_type_columns)

# Print data types of those columns
print("Data types of columns with mixed types:")
print(hourly_data[mixed_type_columns].dtypes)
# Out:
# Columns with mixed types in hourly_data: Index(['HourlyDewPointTemperature', 'HourlyDryBulbTemperature'], dtype='object')
# Data types of columns with mixed types:
# HourlyDewPointTemperature    object
# HourlyDryBulbTemperature     object
# dtype: object

# %%
# Check for missing values
missing_values = merged_data.isnull().sum()
print("Missing Values:")
print(missing_values)
# Out:
# Missing Values:
# STATION_daily                          85575
# DATE                                       0
# REPORT_TYPE_daily                      88243
# SOURCE_daily                           85575
# BackupElements_daily                   88243
#                                        ...
# HourlyVisibility_three_hour            67400
# HourlyWetBulbTemperature_three_hour    67400
# HourlyWindDirection_three_hour         67400
# HourlyWindSpeed_three_hour             67400
# WindEquipmentChangeDate_three_hour     67400
# Length: 119, dtype: int64

# %% [markdown]
# ## 7.3 Summary Statistics

# %%
# Summary statistics
merged_data.describe()
# Out:
#        STATION_daily                           DATE  REPORT_TYPE_daily  \
# count   2.668000e+03                          88243                0.0
# mean    7.251801e+10  2018-09-16 09:13:44.744851968                NaN
# min     7.251801e+10            2015-01-01 00:51:00                NaN
# 25%     7.251801e+10            2016-11-08 03:21:00                NaN
# 50%     7.251801e+10            2018-09-15 22:00:00                NaN
# 75%     7.251801e+10            2020-07-25 02:21:00                NaN
# max     7.251801e+10            2022-05-31 23:59:00                NaN
# std     0.000000e+00                            NaN                NaN
#
#        SOURCE_daily  BackupElements_daily  BackupElevation_daily  \
# count        2668.0                   0.0                 2668.0
# mean            6.0                   NaN                  260.0
# min             6.0                   NaN                  260.0
# 25%             6.0                   NaN                  260.0
# ...

# %% [markdown]
# ## 7.4 Distribution of Weather Report Type

# %%
# Replace 'REPORT_TYPE' with the actual column name in your datasets
report_types_daily = daily_data['REPORT_TYPE'].value_counts()
report_types_hourly = hourly_data['REPORT_TYPE'].value_counts()
report_types_three_hour = three_hour_data['REPORT_TYPE'].value_counts()

# Combine counts from all datasets
combined_report_types = report_types_daily.add(report_types_hourly, fill_value=0)
combined_report_types = combined_report_types.add(report_types_three_hour, fill_value=0)

# Plot the pie chart with previous colors
plt.figure(figsize=(10, 6))
colors = plt.cm.tab10.colors  # Using tab10 colormap for consistent colors
combined_report_types.plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=colors)

# Add a legend
plt.legend(combined_report_types.index, title='Weather Report Types', loc='center left', bbox_to_anchor=(1, 0.5))

plt.title('Distribution of Weather Report Types')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# # **|| END OF NOTEBOOK ||**
